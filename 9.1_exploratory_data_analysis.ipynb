# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

##os.chdir('data_sets')
os.getcwd()
os.listdir()

df = pd.read_csv('IRIS.csv')

# %%
df.shape                                                 #retrieving number of data items
# Out:
# (150, 5)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.loc[df["species"]=="Iris-setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.columns                     ###retrieving all the attributes
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].value_counts()                      ###counting all the number of data items belonging to each species
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
##this is how we can use plt to plot scatter graph between sepal lengthand sepal width but it is lenthy we can use concise way
### to plot this graph

plt.plot(df['sepal_length'][df.species=="Iris-setosa"],df['sepal_width'][df.species=="Iris-setosa"],'o',label="setosa")
plt.plot(df['sepal_length'][df.species=="Iris-virginica"],df['sepal_width'][df.species=="Iris-virginica"],'o',label="virginica")
plt.plot(df['sepal_length'][df.species=="Iris-versicolor"],df['sepal_width'][df.species=="Iris-versicolor"],'o',label="versicolor")
plt.legend()
plt.grid()
plt.show()

# %%
## we can also use this concise way

df.plot(kind="scatter",x="sepal_length",y="sepal_width")
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue='species',size=4).\
                    map(plt.scatter,'sepal_length','sepal_width').\
                    add_legend()
plt.show()
# Out:
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %%
len(df['species'].unique())
# Out:
# 3

# %% [markdown]
# # #3-d scatter plot

# %%
# !pip3 install plotly chart-studio

# %% [markdown]
# # 3.3 pair plot

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="species",height=3)
plt.show()

# %% [markdown]
# # histogram ,pdf,cdf

# %%
###histograms are for 1-d scatter plots for one variables

### 1-d scatter plot of petal_length

# %%
import numpy as np
iris_setosa = df.loc[df["species"] == "Iris-setosa"];
iris_virginica = df.loc[df["species"] == "Iris-virginica"];
iris_versicolor = df.loc[df["species"] == "Iris-versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'bo')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'ro')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'go')


plt.show()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %% [markdown]
# # histogram

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue="species",height=6).map(sns.distplot,'petal_length').add_legend()
plt.show()
# Out:
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
### histogram for petal_width

sns.set_style("whitegrid")
sns.FacetGrid(df,hue='species',size=6).map(sns.distplot,'petal_width').add_legend()
plt.show()
# Out:
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %% [markdown]
# # univariate analysis

# %%
#in univariate analysis we use a single variable to plot histogram of the data set and try to find most suitable variable or
##feature that distinguishes them most

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue='species',size=6).map(sns.distplot,'sepal_length').add_legend()
plt.show()
# Out:
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue='species',size=6).map(sns.distplot,'sepal_width').add_legend()
plt.show()
# Out:
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\shri\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %% [markdown]
# # cummulative distributive function

# %%
###cdf tells us at any poin what number of data items below that poin lies

count,bin_edges = np.histogram(iris_setosa['petal_length'], bins=10 ,density=True)

pdf = count/sum(count)                  #here i am calculating fractional pdf 
print(pdf)
print(bin_edges)
### here bin is number of intervals on which you want to create cdf
## if density is kept false then it will return number of samples in the bin else if kept true returns the pdf 
## count of occurance
cdf = np.cumsum(pdf)                           #this returns cdf

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
##iris setosa cdf

count,bin_edges = np.histogram(iris_setosa['petal_length'], bins=10 ,density=True)

pdf = count/sum(count)                  #here i am calculating fractional pdf 
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)                           #this returns cdf

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)


##iris versicolor cdf

count,bin_edges = np.histogram(iris_versicolor['petal_length'], bins=10 ,density=True)

pdf = count/sum(count)                  #here i am calculating fractional pdf 
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)                           #this returns cdf

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)


##iris virginia cdf

count,bin_edges = np.histogram(iris_virginica['petal_length'], bins=10 ,density=True)

pdf = count/sum(count)                  #here i am calculating fractional pdf 
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)                           #this returns cdf

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]

# %% [markdown]
# # mean variance standard-deviation

# %%
print(np.mean(iris_setosa['petal_length']))                       #mean is similar to average

#mean with an outlier
print(np.mean(np.append(iris_setosa['petal_length'],50)))          ##with a single outlier mean is drastically changed
print(np.mean(iris_versicolor['petal_length']))   
print(np.mean(iris_virginica['petal_length']))   

##standard deviation
print("standard deviation")
print(np.std(iris_setosa['petal_length']))                    
print(np.std(iris_versicolor['petal_length']))   
print(np.std(iris_virginica['petal_length']))
# Out:
# 1.464
# 2.4156862745098038
# 4.26
# 5.552
# standard deviation
# 0.17176728442867115
# 0.4651881339845204
# 0.5463478745268441

# %% [markdown]
# # median,percentile,quantile,inter quantile range(IQR),MAD(median absolute difference)

# %%
print(np.median(iris_setosa['petal_length']))
#median with an outlier
print(np.median(np.append(iris_setosa['petal_length'],50)))
print(np.median(iris_versicolor['petal_length']))
print(np.median(iris_virginica['petal_length']))

## quantiles of data point
print("*************************************888")
print(np.percentile(iris_setosa['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_versicolor['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_virginica['petal_length'],np.arange(0,100,25)))


## percentiles of data point
print("*************************************888")
print(np.percentile(iris_setosa['petal_length'],90))
print(np.percentile(iris_versicolor['petal_length'],90))
print(np.percentile(iris_virginica['petal_length'],90))
print("*************************************888")
print("*************************************888")
# Out:
# 1.5
# 1.5
# 4.35
# 5.55
# *************************************888
# [1.    1.4   1.5   1.575]
# [3.   4.   4.35 4.6 ]
# [4.5   5.1   5.55  5.875]
# *************************************888
# 1.7
# 4.8
# 6.3100000000000005
# *************************************888
# *************************************888

# %%
###### MAD

from statsmodels import robust

print(robust.mad(iris_setosa['petal_length']))
print(robust.mad(iris_virginica['petal_length']))
print(robust.mad(iris_versicolor['petal_length']))
# Out:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # box and whiskers

# %%
sns.boxplot(x='species',y='petal_length',data=df)
plt.show()                                           #it is not clear how whiskers are plotted

# %% [markdown]
# # violin plot is combination of histogram and box plot model

# %%
sns.violinplot( x='species' , y='petal_length' , data=df , size=8 )
plt.show()

# %% [markdown]
# # exrcise 3.12

# %% [markdown]
# Download Haberman Cancer Survival dataset from Kaggle. You may have to create a Kaggle account to donwload data. (https://www.kaggle.com/gilsousa/habermans-survival-data-set)
# Perform a similar alanlaysis as above on this dataset with the following sections:
# High level statistics of the dataset: number of points, numer of features, number of classes, data-points per class.
# Explain our objective.
# Perform Univaraite analysis(PDF, CDF, Boxplot, Voilin plots) to understand which features are useful towards classification.
# Perform Bi-variate analysis (scatter plots, pair-plots) to see if combinations of features are useful in classfication.
# Write your observations in english as crisply and unambigously as possible. Always quantify your results.
